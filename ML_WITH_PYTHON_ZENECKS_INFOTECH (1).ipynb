# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  #importing all neccessary modules
data=pd.read_csv('Placement_Data.csv')#displayinf the dataset
print(data)
data=data.drop('sl_no',axis=1) #dropping uneccsary columns

data["gender"] = data["gender"].astype('category')
data["ssc_b"] = data["ssc_b"].astype('category')
data["hsc_b"] = data["hsc_b"].astype('category')
data["degree_t"] = data["degree_t"].astype('category')
data["workex"] = data["workex"].astype('category')
data["specialisation"] = data["specialisation"].astype('category')
data["status"] = data["status"].astype('category')
data["hsc_s"] = data["hsc_s"].astype('category') #preprocessing and data transformation using astype() on certain columns to change datatype to category
data.dtypes

data["gender"] = data["gender"].cat.codes
data["ssc_b"] = data["ssc_b"].cat.codes
data["hsc_b"] = data["hsc_b"].cat.codes
data["degree_t"] = data["degree_t"].cat.codes
data["workex"] = data["workex"].cat.codes
data["specialisation"] = data["specialisation"].cat.codes
data["status"] = data["status"].cat.codes
data["hsc_s"] =data ["hsc_s"].cat.codes  # apply some codes to some columns to convert text to numerical
print(data)


# selecting the features and labels and splitting dataset into features and values using iloc() function
X = data.iloc[:, :-1].values
Y = data.iloc[:, -1].values

# display dependent variables
Y

# dividing the data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,
													test_size=0.2)

# display dataset
data.head()


# creating a classifier using sklearn
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(random_state=0, solver='lbfgs',
						max_iter=1000).fit(X_train,
											Y_train)
# printing the acc
clf.score(X_test, Y_test)

# predicting for random value
clf.predict([[0, 87, 0, 95, 0, 2, 78, 2, 0, 0, 1, 0]])

# creating a Y_pred for test data
Y_pred = clf.predict(X_test)

# display predicted values
Y_pred

# evaluation of the classifier
from sklearn.metrics import confusion_matrix, accuracy_score

# display confusion matrix
print(confusion_matrix(Y_test, Y_pred))

# display accuracy
print(accuracy_score(Y_test, Y_pred))
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s   CGPA   degree_t  \
# 0        1      M  67.00   Others  91.00   Others  Commerce  58.00   Sci&Tech
# 1        2      M  79.33  Central  78.33   Others   Science  77.48   Sci&Tech
# 2        3      M  65.00  Central  68.00  Central      Arts  64.00  Comm&Mgmt
# 3        5      M  85.80  Central  73.60  Central  Commerce  73.30  Comm&Mgmt
# 4        8      M  82.00  Central  64.00  Central   Science  66.00   Sci&Tech
# ..     ...    ...    ...      ...    ...      ...       ...    ...        ...
# 210    199      F  67.00  Central  70.00  Central  Commerce  65.00     Others
# 211    202      M  54.20  Central  63.00   Others   Science  58.00  Comm&Mgmt
# 212    207      M  41.00  Central  42.00  Central   Science  60.00  Comm&Mgmt
# 213    209      F  43.00  Central  60.00   Others   Science  65.00  Comm&Mgmt
# 214    215      M  62.00  Central  58.00   Others   Science  53.00  Comm&Mgmt
#
# ...
